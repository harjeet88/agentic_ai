# %% [markdown]
# <a href="https://colab.research.google.com/github/harjeet88/agentic_ai/blob/main/crew_ai/CV_Matcher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Install required pacakges

# %%
# !pip install --upgrade --quiet  langchain-community

# %%
# !pip install -q -U crewai
# !pip install -q -U duckduckgo-search
# !pip install -q -U crewai_tools
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.6/324.6 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 106.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 107.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.8/138.8 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 70.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 111.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 41.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 116.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 20.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 80.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 107.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 119.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.7/220.7 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 94.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.1/392.1 kB 27.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 74.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 102.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 112.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 27.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 27.0 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.3/606.3 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.3/211.3 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 36.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 67.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 33.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 108.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 93.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.6/304.6 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 94.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.9/438.9 kB 26.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.0/329.0 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 108.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.52.4 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.

# %% [markdown]
# ### Required Packages

# %%
import os

from crewai import Agent, Task, Crew, Process, LLM
#from crewai_tools import tool
from crewai.tools import BaseTool

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
OPENAI_API_KEY=userdata.get('OPENAI_API_KEY')
os.environ["GEMINI_API_KEY"] = GOOGLE_API_KEY
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
if GOOGLE_API_KEY :
  print("GOOGLE_API_KEY is set")
# Out:
# GOOGLE_API_KEY is set

# %% [markdown]
# ### set up the LLM

# %%
#from crewai import Agent, LLM

gemini = LLM(
    api_key=os.getenv("GEMINI_API_KEY"),
    model="gemini/gemini-2.5-flash",
)

# %%
my_llm=gemini

# %% [markdown]
# ### setup tools

# %%
engineering_lead = Agent(
    role = 'Engineering Lead for the engineering team, directing the work of the engineer',
    goal = '''Take the high level requirements described here and prepare a detailed design for the backend developer;
    everything should be in 1 python module; describe the function and method signatures in the module.
    The python module must be completely self-contained, and ready so that it can be tested or have a simple UI built for it.
    Here are the requirements: {requirements}
    The module should be named {module_name} and the class should be named {class_name}''',
    backstory = '''You're a seasoned engineering lead with a knack for writing clear and concise designs.''',
    llm = my_llm,
    verbose=True,
)

# %%
backend_engineer = Agent(
    role = 'Python Engineer who can write code to achieve the design described by the engineering lead',
    goal = '''Write a python module that implements the design described by the engineering lead, in order to achieve the requirements.
    The python module must be completely self-contained, and ready so that it can be tested or have a simple UI built for it.
    Here are the requirements: {requirements}
    The module should be named {module_name} and the class should be named {class_name}''',
    backstory = '''You're a seasoned python engineer with a knack for writing clean, efficient code.
    You follow the design instructions carefully.
    You produce 1 python module named {module_name} that implements the design and achieves the requirements.''',
    llm = my_llm,
    verbose=True,
)

# %%
frontend_engineer = Agent(
    role = 'A Gradio expert to who can write a simple frontend to demonstrate a backend',
    goal = '''Write a gradio UI that demonstrates the given backend, all in one file to be in the same directory as the backend module {module_name}.
    Here are the requirements: {requirements}''',
    backstory = '''You're a seasoned python engineer highly skilled at writing simple Gradio UIs for a backend class.
    You produce a simple gradio UI that demonstrates the given backend class; you write the gradio UI in a module app.py that is in the same directory as the backend module {module_name}.''',
    llm = my_llm,
    verbose=True,
)

# %%
test_engineer = Agent(
    role = 'An engineer with python coding skills who can write unit tests for the given backend module {module_name}',
    goal = '''Write unit tests for the given backend module {module_name} and create a test_{module_name} in the same directory as the backend module.''',
    backstory = '''You're a seasoned QA engineer and software developer who writes great unit tests for python code.''',
    llm = my_llm,
    verbose=True,
)

# %% [markdown]
# ### Tasks to perform

# %%
# Create tasks for your agents
design_task = Task(
  description="""Write a python module that implements the design described by the engineering lead, in order to achieve the requirements.
    Here are the requirements: {requirements}""",
  agent=backend_engineer,
  verbose=True,
  expected_output="""A python module that implements the design and achieves the requirements.
    IMPORTANT: Output ONLY the raw Python code without any markdown formatting, code block delimiters, or backticks.
    The output should be valid Python code that can be directly saved to a file and executed."""

)

# %%
code_task = Task(
  description="""Write a python module that implements the design described by the engineering lead, in order to achieve the requirements.
    Here are the requirements: {requirements}""",
  agent=backend_engineer,
  expected_output="""A python module that implements the design and achieves the requirements.
    IMPORTANT: Output ONLY the raw Python code without any markdown formatting, code block delimiters, or backticks.
    The output should be valid Python code that can be directly saved to a file and executed.""",
  context=[design_task],
  output_file= "output/{module_name}"
)

# %%
frontend_task = Task(
  description="""Write a gradio UI in a module app.py that demonstrates the given backend class in {module_name}.
    Assume there is only 1 user, and keep the UI very simple indeed - just a prototype or demo.
    Here are the requirements: {requirements}""",
  agent=frontend_engineer,
  expected_output="""A gradio UI in module app.py that demonstrates the given backend class.
    The file should be ready so that it can be run as-is, in the same directory as the backend module, and it should import the backend class from {module_name}.
    IMPORTANT: Output ONLY the raw Python code without any markdown formatting, code block delimiters, or backticks.
    The output should be valid Python code that can be directly saved to a file and executed.""",
  context=[code_task],
  output_file= "output/app.py"
)

# %%
test_task = Task(
  description="""Write unit tests for the given backend module {module_name} and create a test_{module_name} in the same directory as the backend module.""",
  agent=test_engineer,
  expected_output="""A test_{module_name} module that tests the given backend module.
    IMPORTANT: Output ONLY the raw Python code without any markdown formatting, code block delimiters, or backticks.
    The output should be valid Python code that can be directly saved to a file and executed.""",
  context=[code_task],
  output_file= "output/test_{module_name}"
)

# %% [markdown]
# ### Create a Crew

# %%
# Instantiate your crew with a sequential process
crew = Crew(
  agents=[engineering_lead,backend_engineer,frontend_engineer,test_engineer],
  tasks=[design_task,code_task,frontend_task,test_task],
  verbose=False, # You can set it to 1 or 2 to different logging levels
)

# %%
crew
# Out:
# Crew(id=254388e8-f9ea-4218-8779-9207ca513e3a, process=Process.sequential, number_of_agents=4, number_of_tasks=4)

# %% [markdown]
# ### Kickoff the crew - let the magic happen

# %%
requirements = """
A simple account management system for a trading simulation platform.
The system should allow users to create an account, deposit funds, and withdraw funds.
The system should allow users to record that they have bought or sold shares, providing a quantity.
The system should calculate the total value of the user's portfolio, and the profit or loss from the initial deposit.
The system should be able to report the holdings of the user at any point in time.
The system should be able to report the profit or loss of the user at any point in time.
The system should be able to list the transactions that the user has made over time.
The system should prevent the user from withdrawing funds that would leave them with a negative balance, or
 from buying more shares than they can afford, or selling shares that they don't have.
 The system has access to a function get_share_price(symbol) which returns the current price of a share, and includes a test implementation that returns fixed prices for AAPL, TSLA, GOOGL.
"""
module_name="accounts.py"
class_name = "Account"

template_input = {"requirements": requirements,"module_name" : module_name, "class_name" :class_name}

# %%
# Get your crew to work!
#result = crew.kickoff()
result = crew.kickoff(inputs=template_input)
# Out:
# # Agent: Python Engineer who can write code to achieve the design described by the engineering lead
# ## Task: Write a python module that implements the design described by the engineering lead, in order to achieve the requirements.
#     Here are the requirements:
# A simple account management system for a trading simulation platform.
# The system should allow users to create an account, deposit funds, and withdraw funds.
# The system should allow users to record that they have bought or sold shares, providing a quantity.
# The system should calculate the total value of the user's portfolio, and the profit or loss from the initial deposit.
# The system should be able to report the holdings of the user at any point in time.
# The system should be able to report the profit or loss of the user at any point in time.
# The system should be able to list the transactions that the user has made over time.
# The system should prevent the user from withdrawing funds that would leave them with a negative balance, or
#  from buying more shares than they can afford, or selling shares that they don't have.
#  The system has access to a function get_share_price(symbol) which returns the current price of a share, and includes a test implementation that returns fixed prices for AAPL, TSLA, GOOGL.
#
#
#
# # Agent: Python Engineer who can write code to achieve the design described by the engineering lead
# ## Final Answer:
# import datetime
#
# def get_share_price(symbol: str) -> float:
#     """
#     Simulates fetching the current share price for a given symbol.
#     For demonstration, returns fixed prices. In a real system, this
#     would fetch live data from a market data provider.
#     """
#     prices = {
#         "AAPL": 170.00,
#         "TSLA": 250.00,
#         "GOOGL": 120.00,
#         "MSFT": 320.00,
#         "AMZN": 130.00,
#     }
#     return prices.get(symbol.upper(), 0.0) # Return 0.0 for unknown symbols or symbols with no price
#
# class Account:
#     """
#     Manages a simple trading simulation account, allowing deposits, withdrawals,
#     buying/selling shares, and reporting portfolio status and transactions.
#     """
#
#     def __init__(self, account_id: str, initial_deposit: float = 0.0):
#         """
#         Initializes a new trading account.
#
#         Args:
#             account_id (str): A unique identifier for the account.
#             initial_deposit (float): An optional initial amount to deposit into the account.
#                                      Must be non-negative.
#         Raises:
#             ValueError: If account_id is not a non-empty string or initial_deposit is negative.
#         """
#         if not isinstance(account_id, str) or not account_id:
#             raise ValueError("Account ID must be a non-empty string.")
#         if not isinstance(initial_deposit, (int, float)) or initial_deposit < 0:
#             raise ValueError("Initial deposit must be a non-negative number.")
#
#         self._account_id = account_id
#         self._balance = 0.0  # Current cash balance
#         # Holdings: {symbol: {'quantity': int, 'total_cost_basis': float}}
#         # total_cost_basis tracks the sum of costs for all shares of a symbol currently held.
#         self._holdings = {}
#         self._transactions = []  # List of transaction records
#         self._total_deposited = 0.0  # Total cash deposited over account lifetime
#         self._total_withdrawn = 0.0  # Total cash withdrawn over account lifetime
#         self._realized_pnl = 0.0  # Accumulated realized profit/loss from share sales
#
#         # Apply initial deposit if provided
#         if initial_deposit > 0:
#             self.deposit(initial_deposit)
#             # Mark the first deposit transaction specifically as initial funding
#             if self._transactions:
#                 self._transactions[-1]['type'] = 'initial_deposit'
#                 self._transactions[-1]['description'] = 'Initial account funding'
#
#     @property
#     def account_id(self) -> str:
#         """Returns the unique identifier for this account."""
#         return self._account_id
#
#     @property
#     def balance(self) -> float:
#         """Returns the current cash balance in the account, rounded to two decimal places."""
#         return round(self._balance, 2)
#
#     def _record_transaction(self, type: str, amount: float, description: str,
#                             symbol: str = None, quantity: int = None, price: float = None,
#                             status: str = "success", reason: str = None, pnl_impact: float = None):
#         """
#         Helper method to record a transaction in the account's transaction history.
#
#         Args:
#             type (str): Type of transaction (e.g., 'deposit', 'withdraw', 'buy', 'sell').
#             amount (float): The monetary amount involved in the transaction.
#             description (str): A brief description of the transaction.
#             symbol (str, optional): Stock symbol if applicable. Defaults to None.
#             quantity (int, optional): Quantity of shares if applicable. Defaults to None.
#             price (float, optional): Price per share if applicable. Defaults to None.
#             status (str): Status of the transaction ('success' or 'fail'). Defaults to "success".
#             reason (str, optional): Reason for failure if status is 'fail'. Defaults to None.
#             pnl_impact (float, optional): Profit/Loss impact for 'sell' transactions. Defaults to None.
#         """
#         transaction = {
#             "timestamp": datetime.datetime.now().isoformat(),
#             "type": type,
#             "amount": round(amount, 2),
#             "description": description,
#             "symbol": symbol,
#             "quantity": quantity,
#             "price": price,
#             "status": status,
#             "reason": reason,
#             "pnl_impact": round(pnl_impact, 2) if pnl_impact is not None else None
#         }
#         self._transactions.append(transaction)
#
#     def deposit(self, amount: float) -> bool:
#         """
#         Deposits funds into the account.
#
#         Args:
#             amount (float): The amount to deposit. Must be positive.
#
#         Returns:
#             bool: True if deposit was successful, False otherwise.
#         """
#         if not isinstance(amount, (int, float)) or amount <= 0:
#             self._record_transaction("deposit", amount, "Failed: Invalid deposit amount",
#                                      status="fail", reason="Amount must be positive.")
#             return False
#         self._balance += amount
#         self._total_deposited += amount
#         self._record_transaction("deposit", amount, f"Deposit of ${amount:.2f}")
#         return True
#
#     def withdraw(self, amount: float) -> bool:
#         """
#         Withdraws funds from the account.
#
#         Args:
#             amount (float): The amount to withdraw. Must be positive.
#
#         Returns:
#             bool: True if withdrawal was successful, False otherwise.
#         """
#         if not isinstance(amount, (int, float)) or amount <= 0:
#             self._record_transaction("withdraw", amount, "Failed: Invalid withdrawal amount",
#                                      status="fail", reason="Amount must be positive.")
#             return False
#         if self._balance - amount < 0:
#             self._record_transaction("withdraw", amount, "Failed: Insufficient balance",
#                                      status="fail", reason="Insufficient balance.")
#             return False
#         self._balance -= amount
#         self._total_withdrawn += amount
#         self._record_transaction("withdraw", amount, f"Withdrawal of ${amount:.2f}")
#         return True
#
#     def buy_shares(self, symbol: str, quantity: int) -> bool:
#         """
#         Buys shares of a specified stock.
#
#         Args:
#             symbol (str): The stock symbol (e.g., 'AAPL').
#             quantity (int): The number of shares to buy. Must be positive.
#
#         Returns:
#             bool: True if purchase was successful, False otherwise.
#         """
#         symbol = symbol.upper() # Standardize symbol casing
#         if not isinstance(symbol, str) or not symbol:
#             self._record_transaction("buy", 0, "Failed: Invalid symbol", status="fail",
#                                      reason="Symbol must be a non-empty string.")
#             return False
#         if not isinstance(quantity, int) or quantity <= 0:
#             self._record_transaction("buy", 0, "Failed: Invalid quantity", symbol=symbol,
#                                      status="fail", reason="Quantity must be a positive integer.")
#             return False
#
#         current_price = get_share_price(symbol)
#         if current_price <= 0:
#             self._record_transaction("buy", 0, f"Failed: Invalid price for {symbol}",
#                                      symbol=symbol, quantity=quantity, status="fail",
#                                      reason="Could not get share price or price is zero/negative.")
#             return False
#
#         total_cost = current_price * quantity
#         if self._balance < total_cost:
#             self._record_transaction("buy", total_cost, "Failed: Insufficient balance",
#                                      symbol=symbol, quantity=quantity, price=current_price,
#                                      status="fail", reason="Insufficient balance to buy shares.")
#             return False
#
#         self._balance -= total_cost
#
#         # Update holdings using average cost basis
#         if symbol not in self._holdings:
#             self._holdings[symbol] = {'quantity': 0, 'total_cost_basis': 0.0}
#
#         self._holdings[symbol]['quantity'] += quantity
#         self._holdings[symbol]['total_cost_basis'] += total_cost
#
#         self._record_transaction("buy", total_cost, f"Bought {quantity} of {symbol} at ${current_price:.2f}",
#                                  symbol=symbol, quantity=quantity, price=current_price)
#         return True
#
#     def sell_shares(self, symbol: str, quantity: int) -> bool:
#         """
#         Sells shares of a specified stock.
#
#         Args:
#             symbol (str): The stock symbol (e.g., 'AAPL').
#             quantity (int): The number of shares to sell. Must be positive.
#
#         Returns:
#             bool: True if sale was successful, False otherwise.
#         """
#         symbol = symbol.upper() # Standardize symbol casing
#         if not isinstance(symbol, str) or not symbol:
#             self._record_transaction("sell", 0, "Failed: Invalid symbol", status="fail",
#                                      reason="Symbol must be a non-empty string.")
#             return False
#         if not isinstance(quantity, int) or quantity <= 0:
#             self._record_transaction("sell", 0, "Failed: Invalid quantity", symbol=symbol,
#                                      status="fail", reason="Quantity must be a positive integer.")
#             return False
#
#         if symbol not in self._holdings or self._holdings[symbol]['quantity'] < quantity:
#             self._record_transaction("sell", 0, "Failed: Insufficient shares", symbol=symbol,
#                                      quantity=quantity, status="fail", reason="Not enough shares to sell.")
#             return False
#
#         current_price = get_share_price(symbol)
#         if current_price <= 0:
#             self._record_transaction("sell", 0, f"Failed: Invalid price for {symbol}",
#                                      symbol=symbol, quantity=quantity, status="fail",
#                                      reason="Could not get share price or price is zero/negative.")
#             return False
#
#         revenue = current_price * quantity
#
#         # Calculate P&L for sold shares based on average cost basis
#         held_quantity = self._holdings[symbol]['quantity']
#         total_cost_basis = self._holdings[symbol]['total_cost_basis']
#
#         realized_pnl_on_sale = 0.0
#         if held_quantity > 0:
#             average_cost_per_share = total_cost_basis / held_quantity
#             cost_of_sold_shares = average_cost_per_share * quantity
#             realized_pnl_on_sale = (current_price - average_cost_per_share) * quantity
#
#             self._holdings[symbol]['quantity'] -= quantity
#             # Deduct the cost basis of sold shares proportionally
#             self._holdings[symbol]['total_cost_basis'] -= cost_of_sold_shares
#
#             self._realized_pnl += realized_pnl_on_sale # Accumulate realized P&L
#         else: # Should ideally not be reached if previous checks are robust, implies zero quantity but still trying to sell
#              # Just to be safe, decrement quantity and set cost basis to 0 if held_quantity was 0
#             self._holdings[symbol]['quantity'] -= quantity
#             self._holdings[symbol]['total_cost_basis'] = 0.0
#
#
#         if self._holdings[symbol]['quantity'] == 0:
#             del self._holdings[symbol] # Remove symbol from holdings if no shares left
#
#         self._balance += revenue
#         self._record_transaction("sell", revenue, f"Sold {quantity} of {symbol} at ${current_price:.2f}",
#                                  symbol=symbol, quantity=quantity, price=current_price, pnl_impact=realized_pnl_on_sale)
#         return True
#
#     def get_holdings(self) -> dict:
#         """
#         Reports the current stock holdings, including quantity, average cost per share,
#         total cost basis, current market price, current market value, and unrealized profit/loss.
#
#         Returns:
#             dict: A dictionary where keys are stock symbols and values are dictionaries
#                   containing detailed holding information.
#         """
#         detailed_holdings = {}
#         for symbol, data in self._holdings.items():
#             quantity = data['quantity']
#             total_cost_basis = data['total_cost_basis']
#             current_price = get_share_price(symbol)
#
#             avg_cost_per_share = round(total_cost_basis / quantity, 2) if quantity > 0 else 0.0
#             current_market_value = round(current_price * quantity, 2)
#
#             detailed_holdings[symbol] = {
#                 'quantity': quantity,
#                 'average_cost_per_share': avg_cost_per_share,
#                 'total_cost_basis': round(total_cost_basis, 2),
#                 'current_price': current_price,
#                 'current_market_value': current_market_value,
#                 'unrealized_profit_loss': round(current_market_value - total_cost_basis, 2)
#             }
#         return detailed_holdings
#
#     def get_portfolio_value(self) -> float:
#         """
#         Calculates the total value of the user's portfolio, which includes
#         the current cash balance plus the current market value of all stock holdings.
#
#         Returns:
#             float: The total portfolio value, rounded to two decimal places.
#         """
#         holdings_market_value = 0.0
#         for symbol, data in self._holdings.items():
#             quantity = data['quantity']
#             current_price = get_share_price(symbol)
#             holdings_market_value += current_price * quantity
#         return round(self._balance + holdings_market_value, 2)
#
#     def get_profit_loss(self) -> dict:
#         """
#         Calculates and reports the overall profit or loss of the account
#         relative to the net cash invested, along with a breakdown of
#         realized and unrealized profit/loss.
#
#         Returns:
#             dict: A dictionary containing:
#                   - 'net_cash_invested': Total deposits minus total withdrawals.
#                   - 'current_portfolio_value': The current total value of the account.
#                   - 'total_profit_loss_overall': Current portfolio value minus net cash invested.
#                   - 'realized_profit_loss': P&L from closed positions (shares that have been sold).
#                   - 'unrealized_profit_loss': P&L from open positions (shares currently held).
#         """
#         net_cash_invested = self._total_deposited - self._total_withdrawn
#         current_portfolio_value = self.get_portfolio_value()
#
#         # Overall P&L relative to net cash invested
#         total_pnl_from_net_investment = round(current_portfolio_value - net_cash_invested, 2)
#
#         # Calculate unrealized P&L from current holdings
#         unrealized_pnl = 0.0
#         for symbol, data in self._holdings.items():
#             quantity = data['quantity']
#             total_cost_basis = data['total_cost_basis']
#             current_price = get_share_price(symbol)
#             unrealized_pnl += (current_price * quantity) - total_cost_basis
#         unrealized_pnl = round(unrealized_pnl, 2)
#
#         # Realized P&L is accumulated from sales transactions
#         realized_pnl_total = round(self._realized_pnl, 2)
#
#         return {
#             "net_cash_invested": round(net_cash_invested, 2),
#             "current_portfolio_value": current_portfolio_value,
#             "total_profit_loss_overall": total_pnl_from_net_investment,
#             "realized_profit_loss": realized_pnl_total,
#             "unrealized_profit_loss": unrealized_pnl
#         }
#
#     def get_transactions(self) -> list:
#         """
#         Returns a chronological list of all transactions made on the account.
#
#         Returns:
#             list: A list of dictionaries, each representing a transaction.
#         """
#         return list(self._transactions) # Return a copy to prevent external modification
#
# ```
#
#
# # Agent: Python Engineer who can write code to achieve the design described by the engineering lead
# ## Task: Write a python module that implements the design described by the engineering lead, in order to achieve the requirements.
#     Here are the requirements:
# A simple account management system for a trading simulation platform.
# The system should allow users to create an account, deposit funds, and withdraw funds.
# The system should allow users to record that they have bought or sold shares, providing a quantity.
# The system should calculate the total value of the user's portfolio, and the profit or loss from the initial deposit.
# The system should be able to report the holdings of the user at any point in time.
# The system should be able to report the profit or loss of the user at any point in time.
# The system should be able to list the transactions that the user has made over time.
# The system should prevent the user from withdrawing funds that would leave them with a negative balance, or
#  from buying more shares than they can afford, or selling shares that they don't have.
#  The system has access to a function get_share_price(symbol) which returns the current price of a share, and includes a test implementation that returns fixed prices for AAPL, TSLA, GOOGL.
#
#
#
# # Agent: Python Engineer who can write code to achieve the design described by the engineering lead
# ## Final Answer:
# import datetime
#
# def get_share_price(symbol: str) -> float:
#     """
#     Simulates fetching the current share price for a given symbol.
#     For demonstration, returns fixed prices. In a real system, this
#     would fetch live data from a market data provider.
#     """
#     prices = {
#         "AAPL": 170.00,
#         "TSLA": 250.00,
#         "GOOGL": 120.00,
#         "MSFT": 320.00,
#         "AMZN": 130.00,
#     }
#     return prices.get(symbol.upper(), 0.0) # Return 0.0 for unknown symbols or symbols with no price
#
# class Account:
#     """
#     Manages a simple trading simulation account, allowing deposits, withdrawals,
#     buying/selling shares, and reporting portfolio status and transactions.
#     """
#
#     def __init__(self, account_id: str, initial_deposit: float = 0.0):
#         """
#         Initializes a new trading account.
#
#         Args:
#             account_id (str): A unique identifier for the account.
#             initial_deposit (float): An optional initial amount to deposit into the account.
#                                      Must be non-negative.
#         Raises:
#             ValueError: If account_id is not a non-empty string or initial_deposit is negative.
#         """
#         if not isinstance(account_id, str) or not account_id:
#             raise ValueError("Account ID must be a non-empty string.")
#         if not isinstance(initial_deposit, (int, float)) or initial_deposit < 0:
#             raise ValueError("Initial deposit must be a non-negative number.")
#
#         self._account_id = account_id
#         self._balance = 0.0  # Current cash balance
#         # Holdings: {symbol: {'quantity': int, 'total_cost_basis': float}}
#         # total_cost_basis tracks the sum of costs for all shares of a symbol currently held.
#         self._holdings = {}
#         self._transactions = []  # List of transaction records
#         self._total_deposited = 0.0  # Total cash deposited over account lifetime
#         self._total_withdrawn = 0.0  # Total cash withdrawn over account lifetime
#         self._realized_pnl = 0.0  # Accumulated realized profit/loss from share sales
#
#         # Apply initial deposit if provided
#         if initial_deposit > 0:
#             self.deposit(initial_deposit)
#             # Mark the first deposit transaction specifically as initial funding
#             if self._transactions:
#                 self._transactions[-1]['type'] = 'initial_deposit'
#                 self._transactions[-1]['description'] = 'Initial account funding'
#
#     @property
#     def account_id(self) -> str:
#         """Returns the unique identifier for this account."""
#         return self._account_id
#
#     @property
#     def balance(self) -> float:
#         """Returns the current cash balance in the account, rounded to two decimal places."""
#         return round(self._balance, 2)
#
#     def _record_transaction(self, type: str, amount: float, description: str,
#                             symbol: str = None, quantity: int = None, price: float = None,
#                             status: str = "success", reason: str = None, pnl_impact: float = None):
#         """
#         Helper method to record a transaction in the account's transaction history.
#
#         Args:
#             type (str): Type of transaction (e.g., 'deposit', 'withdraw', 'buy', 'sell').
#             amount (float): The monetary amount involved in the transaction.
#             description (str): A brief description of the transaction.
#             symbol (str, optional): Stock symbol if applicable. Defaults to None.
#             quantity (int, optional): Quantity of shares if applicable. Defaults to None.
#             price (float, optional): Price per share if applicable. Defaults to None.
#             status (str): Status of the transaction ('success' or 'fail'). Defaults to "success".
#             reason (str, optional): Reason for failure if status is 'fail'. Defaults to None.
#             pnl_impact (float, optional): Profit/Loss impact for 'sell' transactions. Defaults to None.
#         """
#         transaction = {
#             "timestamp": datetime.datetime.now().isoformat(),
#             "type": type,
#             "amount": round(amount, 2),
#             "description": description,
#             "symbol": symbol,
#             "quantity": quantity,
#             "price": price,
#             "status": status,
#             "reason": reason,
#             "pnl_impact": round(pnl_impact, 2) if pnl_impact is not None else None
#         }
#         self._transactions.append(transaction)
#
#     def deposit(self, amount: float) -> bool:
#         """
#         Deposits funds into the account.
#
#         Args:
#             amount (float): The amount to deposit. Must be positive.
#
#         Returns:
#             bool: True if deposit was successful, False otherwise.
#         """
#         if not isinstance(amount, (int, float)) or amount <= 0:
#             self._record_transaction("deposit", amount, "Failed: Invalid deposit amount",
#                                      status="fail", reason="Amount must be positive.")
#             return False
#         self._balance += amount
#         self._total_deposited += amount
#         self._record_transaction("deposit", amount, f"Deposit of ${amount:.2f}")
#         return True
#
#     def withdraw(self, amount: float) -> bool:
#         """
#         Withdraws funds from the account.
#
#         Args:
#             amount (float): The amount to withdraw. Must be positive.
#
#         Returns:
#             bool: True if withdrawal was successful, False otherwise.
#         """
#         if not isinstance(amount, (int, float)) or amount <= 0:
#             self._record_transaction("withdraw", amount, "Failed: Invalid withdrawal amount",
#                                      status="fail", reason="Amount must be positive.")
#             return False
#         if self._balance - amount < 0:
#             self._record_transaction("withdraw", amount, "Failed: Insufficient balance",
#                                      status="fail", reason="Insufficient balance.")
#             return False
#         self._balance -= amount
#         self._total_withdrawn += amount
#         self._record_transaction("withdraw", amount, f"Withdrawal of ${amount:.2f}")
#         return True
#
#     def buy_shares(self, symbol: str, quantity: int) -> bool:
#         """
#         Buys shares of a specified stock.
#
#         Args:
#             symbol (str): The stock symbol (e.g., 'AAPL').
#             quantity (int): The number of shares to buy. Must be positive.
#
#         Returns:
#             bool: True if purchase was successful, False otherwise.
#         """
#         symbol = symbol.upper() # Standardize symbol casing
#         if not isinstance(symbol, str) or not symbol:
#             self._record_transaction("buy", 0, "Failed: Invalid symbol", status="fail",
#                                      reason="Symbol must be a non-empty string.")
#             return False
#         if not isinstance(quantity, int) or quantity <= 0:
#             self._record_transaction("buy", 0, "Failed: Invalid quantity", symbol=symbol,
#                                      status="fail", reason="Quantity must be a positive integer.")
#             return False
#
#         current_price = get_share_price(symbol)
#         if current_price <= 0:
#             self._record_transaction("buy", 0, f"Failed: Invalid price for {symbol}",
#                                      symbol=symbol, quantity=quantity, status="fail",
#                                      reason="Could not get share price or price is zero/negative.")
#             return False
#
#         total_cost = current_price * quantity
#         if self._balance < total_cost:
#             self._record_transaction("buy", total_cost, "Failed: Insufficient balance",
#                                      symbol=symbol, quantity=quantity, price=current_price,
#                                      status="fail", reason="Insufficient balance to buy shares.")
#             return False
#
#         self._balance -= total_cost
#
#         # Update holdings using average cost basis
#         if symbol not in self._holdings:
#             self._holdings[symbol] = {'quantity': 0, 'total_cost_basis': 0.0}
#
#         self._holdings[symbol]['quantity'] += quantity
#         self._holdings[symbol]['total_cost_basis'] += total_cost
#
#         self._record_transaction("buy", total_cost, f"Bought {quantity} of {symbol} at ${current_price:.2f}",
#                                  symbol=symbol, quantity=quantity, price=current_price)
#         return True
#
#     def sell_shares(self, symbol: str, quantity: int) -> bool:
#         """
#         Sells shares of a specified stock.
#
#         Args:
#             symbol (str): The stock symbol (e.g., 'AAPL').
#             quantity (int): The number of shares to sell. Must be positive.
#
#         Returns:
#             bool: True if sale was successful, False otherwise.
#         """
#         symbol = symbol.upper() # Standardize symbol casing
#         if not isinstance(symbol, str) or not symbol:
#             self._record_transaction("sell", 0, "Failed: Invalid symbol", status="fail",
#                                      reason="Symbol must be a non-empty string.")
#             return False
#         if not isinstance(quantity, int) or quantity <= 0:
#             self._record_transaction("sell", 0, "Failed: Invalid quantity", symbol=symbol,
#                                      status="fail", reason="Quantity must be a positive integer.")
#             return False
#
#         if symbol not in self._holdings or self._holdings[symbol]['quantity'] < quantity:
#             self._record_transaction("sell", 0, "Failed: Insufficient shares", symbol=symbol,
#                                      quantity=quantity, status="fail", reason="Not enough shares to sell.")
#             return False
#
#         current_price = get_share_price(symbol)
#         if current_price <= 0:
#             self._record_transaction("sell", 0, f"Failed: Invalid price for {symbol}",
#                                      symbol=symbol, quantity=quantity, status="fail",
#                                      reason="Could not get share price or price is zero/negative.")
#             return False
#
#         revenue = current_price * quantity
#
#         # Calculate P&L for sold shares based on average cost basis
#         held_quantity = self._holdings[symbol]['quantity']
#         total_cost_basis = self._holdings[symbol]['total_cost_basis']
#
#         realized_pnl_on_sale = 0.0
#         if held_quantity > 0:
#             average_cost_per_share = total_cost_basis / held_quantity
#             cost_of_sold_shares = average_cost_per_share * quantity
#             realized_pnl_on_sale = (current_price - average_cost_per_share) * quantity
#
#             self._holdings[symbol]['quantity'] -= quantity
#             # Deduct the cost basis of sold shares proportionally
#             self._holdings[symbol]['total_cost_basis'] -= cost_of_sold_shares
#
#             self._realized_pnl += realized_pnl_on_sale # Accumulate realized P&L
#         else: # Should ideally not be reached if previous checks are robust, implies zero quantity but still trying to sell
#              # Just to be safe, decrement quantity and set cost basis to 0 if held_quantity was 0
#             self._holdings[symbol]['quantity'] -= quantity
#             self._holdings[symbol]['total_cost_basis'] = 0.0
#
#
#         if self._holdings[symbol]['quantity'] == 0:
#             del self._holdings[symbol] # Remove symbol from holdings if no shares left
#
#         self._balance += revenue
#         self._record_transaction("sell", revenue, f"Sold {quantity} of {symbol} at ${current_price:.2f}",
#                                  symbol=symbol, quantity=quantity, price=current_price, pnl_impact=realized_pnl_on_sale)
#         return True
#
#     def get_holdings(self) -> dict:
#         """
#         Reports the current stock holdings, including quantity, average cost per share,
#         total cost basis, current market price, current market value, and unrealized profit/loss.
#
#         Returns:
#             dict: A dictionary where keys are stock symbols and values are dictionaries
#                   containing detailed holding information.
#         """
#         detailed_holdings = {}
#         for symbol, data in self._holdings.items():
#             quantity = data['quantity']
#             total_cost_basis = data['total_cost_basis']
#             current_price = get_share_price(symbol)
#
#             avg_cost_per_share = round(total_cost_basis / quantity, 2) if quantity > 0 else 0.0
#             current_market_value = round(current_price * quantity, 2)
#
#             detailed_holdings[symbol] = {
#                 'quantity': quantity,
#                 'average_cost_per_share': avg_cost_per_share,
#                 'total_cost_basis': round(total_cost_basis, 2),
#                 'current_price': current_price,
#                 'current_market_value': current_market_value,
#                 'unrealized_profit_loss': round(current_market_value - total_cost_basis, 2)
#             }
#         return detailed_holdings
#
#     def get_portfolio_value(self) -> float:
#         """
#         Calculates the total value of the user's portfolio, which includes
#         the current cash balance plus the current market value of all stock holdings.
#
#         Returns:
#             float: The total portfolio value, rounded to two decimal places.
#         """
#         holdings_market_value = 0.0
#         for symbol, data in self._holdings.items():
#             quantity = data['quantity']
#             current_price = get_share_price(symbol)
#             holdings_market_value += current_price * quantity
#         return round(self._balance + holdings_market_value, 2)
#
#     def get_profit_loss(self) -> dict:
#         """
#         Calculates and reports the overall profit or loss of the account
#         relative to the net cash invested, along with a breakdown of
#         realized and unrealized profit/loss.
#
#         Returns:
#             dict: A dictionary containing:
#                   - 'net_cash_invested': Total deposits minus total withdrawals.
#                   - 'current_portfolio_value': The current total value of the account.
#                   - 'total_profit_loss_overall': Current portfolio value minus net cash invested.
#                   - 'realized_profit_loss': P&L from closed positions (shares that have been sold).
#                   - 'unrealized_profit_loss': P&L from open positions (shares currently held).
#         """
#         net_cash_invested = self._total_deposited - self._total_withdrawn
#         current_portfolio_value = self.get_portfolio_value()
#
#         # Overall P&L relative to net cash invested
#         total_pnl_from_net_investment = round(current_portfolio_value - net_cash_invested, 2)
#
#         # Calculate unrealized P&L from current holdings
#         unrealized_pnl = 0.0
#         for symbol, data in self._holdings.items():
#             quantity = data['quantity']
#             total_cost_basis = data['total_cost_basis']
#             current_price = get_share_price(symbol)
#             unrealized_pnl += (current_price * quantity) - total_cost_basis
#         unrealized_pnl = round(unrealized_pnl, 2)
#
#         # Realized P&L is accumulated from sales transactions
#         realized_pnl_total = round(self._realized_pnl, 2)
#
#         return {
#             "net_cash_invested": round(net_cash_invested, 2),
#             "current_portfolio_value": current_portfolio_value,
#             "total_profit_loss_overall": total_pnl_from_net_investment,
#             "realized_profit_loss": realized_pnl_total,
#             "unrealized_profit_loss": unrealized_pnl
#         }
#
#     def get_transactions(self) -> list:
#         """
#         Returns a chronological list of all transactions made on the account.
#
#         Returns:
#             list: A list of dictionaries, each representing a transaction.
#         """
#         return list(self._transactions) # Return a copy to prevent external modification
#
#
# # Agent: A Gradio expert to who can write a simple frontend to demonstrate a backend
# ## Task: Write a gradio UI in a module app.py that demonstrates the given backend class in accounts.py.
#     Assume there is only 1 user, and keep the UI very simple indeed - just a prototype or demo.
#     Here are the requirements:
# A simple account management system for a trading simulation platform.
# The system should allow users to create an account, deposit funds, and withdraw funds.
# The system should allow users to record that they have bought or sold shares, providing a quantity.
# The system should calculate the total value of the user's portfolio, and the profit or loss from the initial deposit.
# The system should be able to report the holdings of the user at any point in time.
# The system should be able to report the profit or loss of the user at any point in time.
# The system should be able to list the transactions that the user has made over time.
# The system should prevent the user from withdrawing funds that would leave them with a negative balance, or
#  from buying more shares than they can afford, or selling shares that they don't have.
#  The system has access to a function get_share_price(symbol) which returns the current price of a share, and includes a test implementation that returns fixed prices for AAPL, TSLA, GOOGL.
#
#
#
# # Agent: A Gradio expert to who can write a simple frontend to demonstrate a backend
# ## Final Answer:
# import gradio as gr
# import datetime
#
# # --- Backend Code (as provided in context) ---
# # NOTE: In a real multi-file project, you would typically import these from accounts.py
# # For this specific task, if `app.py` is the only file, these definitions are included.
# # Assuming accounts.py exists in the same directory and we are importing from it as per instructions.
#
# # This function would typically be in accounts.py or a separate pricing module
# def get_share_price(symbol: str) -> float:
#     """
#     Simulates fetching the current share price for a given symbol.
#     For demonstration, returns fixed prices. In a real system, this
#     would fetch live data from a market data provider.
#     """
#     prices = {
#         "AAPL": 170.00,
#         "TSLA": 250.00,
#         "GOOGL": 120.00,
#         "MSFT": 320.00,
#         "AMZN": 130.00,
#     }
#     return prices.get(symbol.upper(), 0.0) # Return 0.0 for unknown symbols or symbols with no price
#
# class Account:
#     """
#     Manages a simple trading simulation account, allowing deposits, withdrawals,
#     buying/selling shares, and reporting portfolio status and transactions.
#     """
#
#     def __init__(self, account_id: str, initial_deposit: float = 0.0):
#         """
#         Initializes a new trading account.
#
#         Args:
#             account_id (str): A unique identifier for the account.
#             initial_deposit (float): An optional initial amount to deposit into the account.
#                                      Must be non-negative.
#         Raises:
#             ValueError: If account_id is not a non-empty string or initial_deposit is negative.
#         """
#         if not isinstance(account_id, str) or not account_id:
#             raise ValueError("Account ID must be a non-empty string.")
#         if not isinstance(initial_deposit, (int, float)) or initial_deposit < 0:
#             raise ValueError("Initial deposit must be a non-negative number.")
#
#         self._account_id = account_id
#         self._balance = 0.0  # Current cash balance
#         # Holdings: {symbol: {'quantity': int, 'total_cost_basis': float}}
#         # total_cost_basis tracks the sum of costs for all shares of a symbol currently held.
#         self._holdings = {}
#         self._transactions = []  # List of transaction records
#         self._total_deposited = 0.0  # Total cash deposited over account lifetime
#         self._total_withdrawn = 0.0  # Total cash withdrawn over account lifetime
#         self._realized_pnl = 0.0  # Accumulated realized profit/loss from share sales
#
#         # Apply initial deposit if provided
#         if initial_deposit > 0:
#             self.deposit(initial_deposit)
#             # Mark the first deposit transaction specifically as initial funding
#             if self._transactions:
#                 self._transactions[-1]['type'] = 'initial_deposit'
#                 self._transactions[-1]['description'] = 'Initial account funding'
#
#     @property
#     def account_id(self) -> str:
#         """Returns the unique identifier for this account."""
#         return self._account_id
#
#     @property
#     def balance(self) -> float:
#         """Returns the current cash balance in the account, rounded to two decimal places."""
#         return round(self._balance, 2)
#
#     def _record_transaction(self, type: str, amount: float, description: str,
#                             symbol: str = None, quantity: int = None, price: float = None,
#                             status: str = "success", reason: str = None, pnl_impact: float = None):
#         """
#         Helper method to record a transaction in the account's transaction history.
#
#         Args:
#             type (str): Type of transaction (e.g., 'deposit', 'withdraw', 'buy', 'sell').
#             amount (float): The monetary amount involved in the transaction.
#             description (str): A brief description of the transaction.
#             symbol (str, optional): Stock symbol if applicable. Defaults to None.
#             quantity (int, optional): Quantity of shares if applicable. Defaults to None.
#             price (float, optional): Price per share if applicable. Defaults to None.
#             status (str): Status of the transaction ('success' or 'fail'). Defaults to "success".
#             reason (str, optional): Reason for failure if status is 'fail'. Defaults to None.
#             pnl_impact (float, optional): Profit/Loss impact for 'sell' transactions. Defaults to None.
#         """
#         transaction = {
#             "timestamp": datetime.datetime.now().isoformat(),
#             "type": type,
#             "amount": round(amount, 2),
#             "description": description,
#             "symbol": symbol,
#             "quantity": quantity,
#             "price": price,
#             "status": status,
#             "reason": reason,
#             "pnl_impact": round(pnl_impact, 2) if pnl_impact is not None else None
#         }
#         self._transactions.append(transaction)
#
#     def deposit(self, amount: float) -> bool:
#         """
#         Deposits funds into the account.
#
#         Args:
#             amount (float): The amount to deposit. Must be positive.
#
#         Returns:
#             bool: True if deposit was successful, False otherwise.
#         """
#         if not isinstance(amount, (int, float)) or amount <= 0:
#             self._record_transaction("deposit", amount, "Failed: Invalid deposit amount",
#                                      status="fail", reason="Amount must be positive.")
#             return False
#         self._balance += amount
#         self._total_deposited += amount
#         self._record_transaction("deposit", amount, f"Deposit of ${amount:.2f}")
#         return True
#
#     def withdraw(self, amount: float) -> bool:
#         """
#         Withdraws funds from the account.
#
#         Args:
#             amount (float): The amount to withdraw. Must be positive.
#
#         Returns:
#             bool: True if withdrawal was successful, False otherwise.
#         """
#         if not isinstance(amount, (int, float)) or amount <= 0:
#             self._record_transaction("withdraw", amount, "Failed: Invalid withdrawal amount",
#                                      status="fail", reason="Amount must be positive.")
#             return False
#         if self._balance - amount < 0:
#             self._record_transaction("withdraw", amount, "Failed: Insufficient balance",
#                                      status="fail", reason="Insufficient balance.")
#             return False
#         self._balance -= amount
#         self._total_withdrawn += amount
#         self._record_transaction("withdraw", amount, f"Withdrawal of ${amount:.2f}")
#         return True
#
#     def buy_shares(self, symbol: str, quantity: int) -> bool:
#         """
#         Buys shares of a specified stock.
#
#         Args:
#             symbol (str): The stock symbol (e.g., 'AAPL').
#             quantity (int): The number of shares to buy. Must be positive.
#
#         Returns:
#             bool: True if purchase was successful, False otherwise.
#         """
#         symbol = symbol.upper() # Standardize symbol casing
#         if not isinstance(symbol, str) or not symbol:
#             self._record_transaction("buy", 0, "Failed: Invalid symbol", status="fail",
#                                      reason="Symbol must be a non-empty string.")
#             return False
#         if not isinstance(quantity, int) or quantity <= 0:
#             self._record_transaction("buy", 0, "Failed: Invalid quantity", symbol=symbol,
#                                      status="fail", reason="Quantity must be a positive integer.")
#             return False
#
#         current_price = get_share_price(symbol)
#         if current_price <= 0:
#             self._record_transaction("buy", 0, f"Failed: Invalid price for {symbol}",
#                                      symbol=symbol, quantity=quantity, status="fail",
#                                      reason="Could not get share price or price is zero/negative.")
#             return False
#
#         total_cost = current_price * quantity
#         if self._balance < total_cost:
#             self._record_transaction("buy", total_cost, "Failed: Insufficient balance",
#                                      symbol=symbol, quantity=quantity, price=current_price,
#                                      status="fail", reason="Insufficient balance to buy shares.")
#             return False
#
#         self._balance -= total_cost
#
#         # Update holdings using average cost basis
#         if symbol not in self._holdings:
#             self._holdings[symbol] = {'quantity': 0, 'total_cost_basis': 0.0}
#
#         self._holdings[symbol]['quantity'] += quantity
#         self._holdings[symbol]['total_cost_basis'] += total_cost
#
#         self._record_transaction("buy", total_cost, f"Bought {quantity} of {symbol} at ${current_price:.2f}",
#                                  symbol=symbol, quantity=quantity, price=current_price)
#         return True
#
#     def sell_shares(self, symbol: str, quantity: int) -> bool:
#         """
#         Sells shares of a specified stock.
#
#         Args:
#             symbol (str): The stock symbol (e.g., 'AAPL').
#             quantity (int): The number of shares to sell. Must be positive.
#
#         Returns:
#             bool: True if sale was successful, False otherwise.
#         """
#         symbol = symbol.upper() # Standardize symbol casing
#         if not isinstance(symbol, str) or not symbol:
#             self._record_transaction("sell", 0, "Failed: Invalid symbol", status="fail",
#                                      reason="Symbol must be a non-empty string.")
#             return False
#         if not isinstance(quantity, int) or quantity <= 0:
#             self._record_transaction("sell", 0, "Failed: Invalid quantity", symbol=symbol,
#                                      status="fail", reason="Quantity must be a positive integer.")
#             return False
#
#         if symbol not in self._holdings or self._holdings[symbol]['quantity'] < quantity:
#             self._record_transaction("sell", 0, "Failed: Insufficient shares", symbol=symbol,
#                                      quantity=quantity, status="fail", reason="Not enough shares to sell.")
#             return False
#
#         current_price = get_share_price(symbol)
#         if current_price <= 0:
#             self._record_transaction("sell", 0, f"Failed: Invalid price for {symbol}",
#                                      symbol=symbol, quantity=quantity, status="fail",
#                                      reason="Could not get share price or price is zero/negative.")
#             return False
#
#         revenue = current_price * quantity
#
#         # Calculate P&L for sold shares based on average cost basis
#         held_quantity = self._holdings[symbol]['quantity']
#         total_cost_basis = self._holdings[symbol]['total_cost_basis']
#
#         realized_pnl_on_sale = 0.0
#         if held_quantity > 0:
#             average_cost_per_share = total_cost_basis / held_quantity
#             cost_of_sold_shares = average_cost_per_share * quantity
#             realized_pnl_on_sale = (current_price - average_cost_per_share) * quantity
#
#             self._holdings[symbol]['quantity'] -= quantity
#             # Deduct the cost basis of sold shares proportionally
#             self._holdings[symbol]['total_cost_basis'] -= cost_of_sold_shares
#
#             self._realized_pnl += realized_pnl_on_sale # Accumulate realized P&L
#         else: # Should ideally not be reached if previous checks are robust, implies zero quantity but still trying to sell
#              # Just to be safe, decrement quantity and set cost basis to 0 if held_quantity was 0
#             self._holdings[symbol]['quantity'] -= quantity
#             self._holdings[symbol]['total_cost_basis'] = 0.0
#
#
#         if self._holdings[symbol]['quantity'] == 0:
#             del self._holdings[symbol] # Remove symbol from holdings if no shares left
#
#         self._balance += revenue
#         self._record_transaction("sell", revenue, f"Sold {quantity} of {symbol} at ${current_price:.2f}",
# ...
#         self.assertEqual(acc._transactions[1]['type'], 'buy')
#         self.assertEqual(acc._transactions[1]['symbol'], 'AAPL')
#         self.assertEqual(acc._transactions[1]['quantity'], 10)
#         self.assertEqual(acc._transactions[1]['price'], 170.00)
#
#         # Buy more AAPL, test average cost basis
#         self.mock_get_share_price.side_effect = lambda s: 180.00 if s == "AAPL" else self._mock_prices(s)
#         self.assertTrue(acc.buy_shares("AAPL", 5)) # New price is 180, but cost basis still average
#         self.assertEqual(acc.balance, 10000.0 - (170.00 * 10) - (180.00 * 5))
#         self.assertEqual(acc._holdings["AAPL"]["quantity"], 15)
#         # (170 * 10) + (180 * 5) = 1700 + 900 = 2600
#         self.assertEqual(acc._holdings["AAPL"]["total_cost_basis"], 2600.0)
#         self.assertEqual(len(acc._transactions), 3)
#
#         # Buy TSLA
#         self.mock_get_share_price.side_effect = self._mock_prices # Reset to default
#         self.assertTrue(acc.buy_shares("TSLA", 2))
#         self.assertEqual(acc.balance, 10000.0 - (170.00 * 10) - (180.00 * 5) - (250.00 * 2))
#         self.assertEqual(acc._holdings["TSLA"]["quantity"], 2)
#         self.assertEqual(acc._holdings["TSLA"]["total_cost_basis"], 500.0)
#         self.assertEqual(len(acc._holdings), 2) # Now holds AAPL and TSLA
#
#     def test_buy_shares_insufficient_balance(self):
#         acc = accounts.Account("BACC", 100.0) # Only 100 balance
#         self.assertFalse(acc.buy_shares("AAPL", 1)) # AAPL is 170.00
#         self.assertEqual(acc.balance, 100.0)
#         self.assertEqual(acc._holdings, {})
#         self.assertEqual(len(acc._transactions), 2) # Initial deposit + failed buy
#         self.assertEqual(acc._transactions[1]['status'], 'fail')
#         self.assertEqual(acc._transactions[1]['reason'], 'Insufficient balance to buy shares.')
#
#     def test_buy_shares_invalid_symbol(self):
#         acc = accounts.Account("BACC", 1000.0)
#         self.assertFalse(acc.buy_shares("", 1))
#         self.assertEqual(len(acc._transactions), 2)
#         self.assertEqual(acc._transactions[1]['status'], 'fail')
#         self.assertEqual(acc._transactions[1]['reason'], 'Symbol must be a non-empty string.')
#         self.assertFalse(acc.buy_shares(None, 1))
#
#     def test_buy_shares_invalid_quantity(self):
#         acc = accounts.Account("BACC", 1000.0)
#         self.assertFalse(acc.buy_shares("AAPL", 0))
#         self.assertEqual(len(acc._transactions), 2)
#         self.assertEqual(acc._transactions[1]['status'], 'fail')
#         self.assertEqual(acc._transactions[1]['reason'], 'Quantity must be a positive integer.')
#         self.assertFalse(acc.buy_shares("AAPL", -5))
#         self.assertFalse(acc.buy_shares("AAPL", 1.5))
#
#     def test_buy_shares_unknown_symbol_price(self):
#         acc = accounts.Account("BACC", 1000.0)
#         # Mock get_share_price to return 0 for 'UNKNOWN'
#         self.mock_get_share_price.side_effect = self._mock_prices
#         self.assertFalse(acc.buy_shares("UNKNOWN", 10))
#         self.assertEqual(acc.balance, 1000.0)
#         self.assertEqual(len(acc._transactions), 2)
#         self.assertEqual(acc._transactions[1]['status'], 'fail')
#         self.assertEqual(acc._transactions[1]['reason'], 'Could not get share price or price is zero/negative.')
#
#     def test_sell_shares_success_full(self):
#         acc = accounts.Account("SACC", 5000.0)
#         acc.buy_shares("AAPL", 10) # Cost 1700
#         self.mock_get_share_price.side_effect = lambda s: 190.00 if s == "AAPL" else self._mock_prices(s) # Price increased
#
#         initial_balance = acc.balance
#         self.assertTrue(acc.sell_shares("AAPL", 10))
#         self.assertEqual(acc.balance, initial_balance + (190.00 * 10))
#         self.assertEqual(acc._holdings, {}) # All shares sold, symbol removed
#         self.assertEqual(len(acc._transactions), 3) # Initial, Buy, Sell
#         self.assertEqual(acc._transactions[2]['type'], 'sell')
#         self.assertEqual(acc._transactions[2]['symbol'], 'AAPL')
#         self.assertEqual(acc._transactions[2]['quantity'], 10)
#         self.assertEqual(acc._transactions[2]['price'], 190.00)
#         self.assertEqual(acc._realized_pnl, (190.00 - 170.00) * 10) # P&L: 20 * 10 = 200
#
#     def test_sell_shares_success_partial(self):
#         acc = accounts.Account("SACC", 5000.0)
#         acc.buy_shares("AAPL", 10) # Cost 1700
#         acc.buy_shares("AAPL", 5) # Cost 900 (price 180) -> Total 2600 for 15 shares
#         # Average cost basis is 2600 / 15 = 173.3333...
#
#         self.mock_get_share_price.side_effect = lambda s: 200.00 if s == "AAPL" else self._mock_prices(s) # Sell price 200
#
#         initial_balance = acc.balance
#         self.assertTrue(acc.sell_shares("AAPL", 5)) # Sell 5 shares
#         self.assertEqual(acc.balance, initial_balance + (200.00 * 5))
#         self.assertEqual(acc._holdings["AAPL"]["quantity"], 10)
#
#         # New total cost basis: 2600 - (173.3333... * 5) = 2600 - 866.6666... = 1733.3333...
#         self.assertAlmostEqual(acc._holdings["AAPL"]["total_cost_basis"], 2600 - (2600/15) * 5, places=2)
#
#         # P&L: (200 - 173.3333...) * 5 = 26.6666... * 5 = 133.3333...
#         self.assertAlmostEqual(acc._realized_pnl, (200 - (2600/15)) * 5, places=2)
#
#     def test_sell_shares_not_held(self):
#         acc = accounts.Account("SACC", 1000.0)
#         self.assertFalse(acc.sell_shares("GOOGL", 5))
#         self.assertEqual(acc.balance, 1000.0)
#         self.assertEqual(len(acc._transactions), 2)
#         self.assertEqual(acc._transactions[1]['status'], 'fail')
#         self.assertEqual(acc._transactions[1]['reason'], 'Not enough shares to sell.')
#
#     def test_sell_shares_insufficient_quantity(self):
#         acc = accounts.Account("SACC", 1000.0)
#         acc.buy_shares("MSFT", 5) # Buys 5 MSFT
#         initial_balance = acc.balance
#         self.assertFalse(acc.sell_shares("MSFT", 10)) # Only 5 held
#         self.assertEqual(acc.balance, initial_balance)
#         self.assertEqual(acc._holdings["MSFT"]["quantity"], 5)
#         self.assertEqual(len(acc._transactions), 3) # Initial, Buy, Failed Sell
#         self.assertEqual(acc._transactions[2]['status'], 'fail')
#         self.assertEqual(acc._transactions[2]['reason'], 'Not enough shares to sell.')
#
#     def test_sell_shares_invalid_symbol(self):
#         acc = accounts.Account("SACC", 1000.0)
#         self.assertFalse(acc.sell_shares("", 1))
#         self.assertEqual(len(acc._transactions), 2)
#         self.assertEqual(acc._transactions[1]['status'], 'fail')
#         self.assertEqual(acc._transactions[1]['reason'], 'Symbol must be a non-empty string.')
#
#     def test_sell_shares_invalid_quantity(self):
#         acc = accounts.Account("SACC", 1000.0)
#         acc.buy_shares("AAPL", 10)
#         self.assertFalse(acc.sell_shares("AAPL", 0))
#         self.assertEqual(len(acc._transactions), 3)
#         self.assertEqual(acc._transactions[2]['status'], 'fail')
#         self.assertEqual(acc._transactions[2]['reason'], 'Quantity must be a positive integer.')
#         self.assertFalse(acc.sell_shares("AAPL", -5))
#         self.assertFalse(acc.sell_shares("AAPL", 1.5))
#
#     def test_sell_shares_unknown_symbol_price(self):
#         acc = accounts.Account("SACC", 5000.0)
#         acc.buy_shares("AMZN", 10) # Buys AMZN
#
#         self.mock_get_share_price.side_effect = lambda s: 0.0 if s == "AMZN" else self._mock_prices(s) # Price set to 0 for AMZN
#         self.assertFalse(acc.sell_shares("AMZN", 5))
#         self.assertEqual(acc.balance, 5000.0 - (130.00 * 10)) # Balance unchanged
#         self.assertEqual(acc._holdings["AMZN"]["quantity"], 10) # Holdings unchanged
#         self.assertEqual(len(acc._transactions), 3)
#         self.assertEqual(acc._transactions[2]['status'], 'fail')
#         self.assertEqual(acc._transactions[2]['reason'], 'Could not get share price or price is zero/negative.')
#
#     def test_get_holdings_empty(self):
#         acc = accounts.Account("HACC")
#         self.assertEqual(acc.get_holdings(), {})
#
#     def test_get_holdings_multiple_stocks(self):
#         acc = accounts.Account("HACC", 10000.0)
#         acc.buy_shares("AAPL", 10) # Cost 1700
#         acc.buy_shares("TSLA", 2) # Cost 500
#         acc.buy_shares("GOOGL", 5) # Cost 600
#
#         holdings = acc.get_holdings()
#         self.assertEqual(len(holdings), 3)
#
#         self.assertIn("AAPL", holdings)
#         self.assertEqual(holdings["AAPL"]["quantity"], 10)
#         self.assertEqual(holdings["AAPL"]["average_cost_per_share"], 170.00)
#         self.assertEqual(holdings["AAPL"]["total_cost_basis"], 1700.00)
#         self.assertEqual(holdings["AAPL"]["current_price"], 170.00)
#         self.assertEqual(holdings["AAPL"]["current_market_value"], 1700.00)
#         self.assertEqual(holdings["AAPL"]["unrealized_profit_loss"], 0.0)
#
#         self.assertIn("TSLA", holdings)
#         self.assertEqual(holdings["TSLA"]["quantity"], 2)
#         self.assertEqual(holdings["TSLA"]["average_cost_per_share"], 250.00)
#         self.assertEqual(holdings["TSLA"]["current_price"], 250.00)
#         self.assertEqual(holdings["TSLA"]["unrealized_profit_loss"], 0.0)
#
#         # Test unrealized P&L
#         self.mock_get_share_price.side_effect = lambda s: 150.00 if s == "AAPL" else self._mock_prices(s)
#         holdings_updated = acc.get_holdings()
#         self.assertEqual(holdings_updated["AAPL"]["current_price"], 150.00)
#         self.assertEqual(holdings_updated["AAPL"]["current_market_value"], 1500.00)
#         self.assertEqual(holdings_updated["AAPL"]["unrealized_profit_loss"], 1500.00 - 1700.00) # -200.00
#
#     def test_get_portfolio_value(self):
#         acc = accounts.Account("PVACC", 1000.0) # Cash: 1000
#         self.assertEqual(acc.get_portfolio_value(), 1000.0)
#
#         acc.buy_shares("AAPL", 5) # Buy 5 @ 170 = 850. Cash: 150. Holdings: AAPL 5 @ 170. Market Value 850.
#         self.assertEqual(acc.get_portfolio_value(), 150.0 + (170.00 * 5)) # 150 + 850 = 1000.0
#
#         acc.buy_shares("TSLA", 2) # Buy 2 @ 250 = 500. Cash: -350 (insufficient)
#         # Re-run after mocking more balance.
#         acc_new = accounts.Account("PVACC_NEW", 2000.0)
#         acc_new.buy_shares("AAPL", 5) # Cash: 2000 - 850 = 1150
#         acc_new.buy_shares("TSLA", 2) # Cash: 1150 - 500 = 650
#
#         # Current market value of holdings: (5 * 170) + (2 * 250) = 850 + 500 = 1350
#         # Total portfolio value: 650 (cash) + 1350 (holdings) = 2000
#         self.assertEqual(acc_new.get_portfolio_value(), 650.0 + 1350.0)
#
#         # Test with price changes affecting market value
#         self.mock_get_share_price.side_effect = lambda s: 200.00 if s == "AAPL" else self._mock_prices(s)
#         # New market value of AAPL: 5 * 200 = 1000
#         # Total holdings market value: 1000 + 500 = 1500
#         # Total portfolio value: 650 (cash) + 1500 (holdings) = 2150
#         self.assertEqual(acc_new.get_portfolio_value(), 650.0 + (5 * 200.00) + (2 * 250.00))
#
#     def test_get_profit_loss(self):
#         # Scenario 1: Initial state
#         acc = accounts.Account("PLACC", 0.0)
#         pnl = acc.get_profit_loss()
#         self.assertEqual(pnl["net_cash_invested"], 0.0)
#         self.assertEqual(pnl["current_portfolio_value"], 0.0)
#         self.assertEqual(pnl["total_profit_loss_overall"], 0.0)
#         self.assertEqual(pnl["realized_profit_loss"], 0.0)
#         self.assertEqual(pnl["unrealized_profit_loss"], 0.0)
#
#         # Scenario 2: Deposit and withdraw
#         acc.deposit(1000.0)
#         acc.withdraw(200.0)
#         pnl = acc.get_profit_loss()
#         self.assertEqual(pnl["net_cash_invested"], 800.0)
#         self.assertEqual(pnl["current_portfolio_value"], 800.0)
#         self.assertEqual(pnl["total_profit_loss_overall"], 0.0) # 800 - 800 = 0
#         self.assertEqual(pnl["realized_profit_loss"], 0.0)
#         self.assertEqual(pnl["unrealized_profit_loss"], 0.0)
#
#         # Scenario 3: Buy shares (unrealized P&L)
#         acc.buy_shares("AAPL", 5) # 5 * 170 = 850. Balance 800-850 = -50. Needs more balance for this
#
#         acc_2 = accounts.Account("PLACC2", 1000.0) # Start with 1000
#         acc_2.buy_shares("AAPL", 5) # Cost 850. Balance 150.
#         # Net cash invested: 1000. Current Portfolio Value: 150 (cash) + (5 * 170) = 150 + 850 = 1000
#         pnl = acc_2.get_profit_loss()
#         self.assertEqual(pnl["net_cash_invested"], 1000.0)
#         self.assertEqual(pnl["current_portfolio_value"], 1000.0)
#         self.assertEqual(pnl["total_profit_loss_overall"], 0.0)
#         self.assertEqual(pnl["realized_profit_loss"], 0.0)
#         self.assertEqual(pnl["unrealized_profit_loss"], 0.0)
#
#         # Price changes, unrealized P&L appears
#         self.mock_get_share_price.side_effect = lambda s: 190.00 if s == "AAPL" else self._mock_prices(s)
#         pnl = acc_2.get_profit_loss()
#         # Net cash invested: 1000.
#         # Current Portfolio Value: 150 (cash) + (5 * 190) = 150 + 950 = 1100
#         # Unrealized P&L: (5 * 190) - (5 * 170) = 950 - 850 = 100
#         self.assertEqual(pnl["net_cash_invested"], 1000.0)
#         self.assertEqual(pnl["current_portfolio_value"], 1100.0)
#         self.assertEqual(pnl["total_profit_loss_overall"], 100.0)
#         self.assertEqual(pnl["realized_profit_loss"], 0.0)
#         self.assertEqual(pnl["unrealized_profit_loss"], 100.0)
#
#         # Scenario 4: Sell shares (realized P&L)
#         self.mock_get_share_price.side_effect = lambda s: 200.00 if s == "AAPL" else self._mock_prices(s) # Sell price 200
#         acc_2.sell_shares("AAPL", 3) # Sell 3 shares (cost basis 170/share)
#         # Realized P&L: (200 - 170) * 3 = 30 * 3 = 90
#         # Balance: 150 + (3 * 200) = 150 + 600 = 750
#         # Remaining AAPL: 2 shares, cost basis 2 * 170 = 340
#         # Net cash invested: 1000
#         # Current Portfolio Value: 750 (cash) + (2 * 200) = 750 + 400 = 1150
#         # Total P&L Overall: 1150 - 1000 = 150
#         # Realized P&L: 90
#         # Unrealized P&L: (2 * 200) - (2 * 170) = 400 - 340 = 60
#         pnl = acc_2.get_profit_loss()
#         self.assertEqual(pnl["net_cash_invested"], 1000.0)
#         self.assertEqual(pnl["current_portfolio_value"], 1150.0)
#         self.assertEqual(pnl["total_profit_loss_overall"], 150.0)
#         self.assertEqual(pnl["realized_profit_loss"], 90.0)
#         self.assertEqual(pnl["unrealized_profit_loss"], 60.0) # P&L from remaining 2 shares
#
#     def test_get_transactions(self):
#         acc = accounts.Account("TACC", 100.0)
#         acc.deposit(50.0)
#         acc.withdraw(20.0)
#         acc.buy_shares("AAPL", 1)
#         acc.sell_shares("AAPL", 1)
#
#         transactions = acc.get_transactions()
#         self.assertEqual(len(transactions), 5) # Initial, Deposit, Withdraw, Buy, Sell
#
#         # Verify types and order
#         self.assertEqual(transactions[0]['type'], 'initial_deposit')
#         self.assertEqual(transactions[1]['type'], 'deposit')
#         self.assertEqual(transactions[2]['type'], 'withdraw')
#         self.assertEqual(transactions[3]['type'], 'buy')
#         self.assertEqual(transactions[4]['type'], 'sell')
#
#         # Verify sell transaction P&L impact
#         self.assertAlmostEqual(transactions[4]['pnl_impact'], (170.0 - 170.0) * 1) # Default price, so PNL is 0 for initial sell
#
#         self.mock_get_share_price.side_effect = lambda s: 180.00 if s == "AAPL" else self._mock_prices(s)
#         acc.buy_shares("AAPL", 2) # cost 180 * 2 = 360
#         acc.sell_shares("AAPL", 1) # sell 1 @ 180
#         # PNL = (180 - 180) * 1 = 0.0
#
#         transactions_after_more_trades = acc.get_transactions()
#         self.assertEqual(len(transactions_after_more_trades), 7)
#         self.assertIsNotNone(transactions_after_more_trades[6]['pnl_impact'])
#         self.assertEqual(transactions_after_more_trades[6]['pnl_impact'], 0.0)
#
#         # Test that modifying the returned list does not affect internal state
#         transactions_copy = acc.get_transactions()
#         transactions_copy.pop()
#         self.assertNotEqual(len(transactions_copy), len(acc._transactions))
#         self.assertEqual(len(acc._transactions), 7)
#
#
# if __name__ == '__main__':
#     unittest.main()
#
# ```

# %%
print(result)
# Out:
# import unittest
# import datetime
# from unittest.mock import patch
#
# # Assuming accounts.py is in the same directory and contains the code
# from accounts import get_share_price, Account
#
# class TestGetSharePrice(unittest.TestCase):
#     """
#     Tests for the get_share_price function.
#     """
#     def test_known_symbols(self):
#         """
#         Test that get_share_price returns correct fixed prices for known symbols.
#         """
#         self.assertEqual(get_share_price("AAPL"), 170.00)
#         self.assertEqual(get_share_price("TSLA"), 250.00)
#         self.assertEqual(get_share_price("GOOGL"), 120.00)
#
#     def test_unknown_symbol(self):
#         """
#         Test that get_share_price returns the default price for an unknown symbol.
#         """
#         self.assertEqual(get_share_price("XYZ"), 100.00)
#
#     def test_case_insensitivity(self):
#         """
#         Test that get_share_price handles case-insensitive symbols correctly.
#         """
#         self.assertEqual(get_share_price("aapl"), 170.00)
#         self.assertEqual(get_share_price("TsLa"), 250.00)
#         self.assertEqual(get_share_price("googl"), 120.00)
#         self.assertEqual(get_share_price("xYz"), 100.00)
#
# class TestAccount(unittest.TestCase):
#     """
#     Tests for the Account class, covering initialization, balance management,
#     share trading, and reporting functionalities.
#     """
#     def setUp(self):
#         """
#         Set up a fresh account and mock datetime.datetime.now for consistent timestamps
#         before each test method.
#         """
#         self.account_id = "test_acc_123"
#         self.mock_now = datetime.datetime(2023, 1, 1, 10, 0, 0)
#         # Patch datetime.datetime.now to return a fixed time
#         self.patcher = patch('accounts.datetime.datetime')
#         self.mock_datetime = self.patcher.start()
#         self.mock_datetime.now.return_value = self.mock_now
#         # Ensure that other datetime methods (like __lt__, __gt__) still work if needed
#         self.mock_datetime.side_effect = lambda *args, **kwargs: datetime.datetime(*args, **kwargs)
#
#
#     def tearDown(self):
#         """
#         Stop the datetime patcher after each test method.
#         """
#         self.patcher.stop()
#
#     def test_account_initialization_no_deposit(self):
#         """
#         Test Account initialization with no initial deposit.
#         """
#         account = Account(self.account_id)
#         self.assertEqual(account.account_id, self.account_id)
#         self.assertEqual(account.balance, 0.0)
#         self.assertEqual(account.get_holdings(), {})
#         self.assertEqual(account.get_transactions(), [])
#         self.assertEqual(account._total_capital_contributed, 0.0)
#
#     def test_account_initialization_with_positive_deposit(self):
#         """
#         Test Account initialization with a positive initial deposit.
#         Verify balance, holdings, and that a deposit transaction is recorded.
#         """
#         initial_deposit_amount = 1000.00
#         account = Account(self.account_id, initial_deposit_amount)
#         self.assertEqual(account.account_id, self.account_id)
#         self.assertEqual(account.balance, initial_deposit_amount)
#         self.assertEqual(account.get_holdings(), {})
#         self.assertEqual(len(account.get_transactions()), 1)
#         self.assertEqual(account.get_transactions()[0]["type"], "DEPOSIT")
#         self.assertEqual(account.get_transactions()[0]["amount"], initial_deposit_amount)
#         self.assertEqual(account.get_transactions()[0]["balance_after"], initial_deposit_amount)
#         self.assertEqual(account._total_capital_contributed, initial_deposit_amount)
#
#     def test_account_initialization_with_negative_deposit_raises_error(self):
#         """
#         Test that initializing an Account with a negative deposit raises a ValueError.
#         """
#         with self.assertRaisesRegex(ValueError, "Initial deposit cannot be negative."):
#             Account(self.account_id, -100.00)
#
#     def test_balance_property(self):
#         """
#         Test the balance property returns the current cash balance correctly.
#         """
#         account = Account(self.account_id, 500.00)
#         self.assertEqual(account.balance, 500.00)
#         account.deposit(200.00)
#         self.assertEqual(account.balance, 700.00)
#         account.withdraw(100.00)
#         self.assertEqual(account.balance, 600.00)
#
#     def test_deposit_successful(self):
#         """
#         Test a successful deposit operation.
#         """
#         account = Account(self.account_id)
#         self.assertTrue(account.deposit(500.00))
#         self.assertEqual(account.balance, 500.00)
#         self.assertEqual(account._total_capital_contributed, 500.00)
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 1)
#         self.assertEqual(transactions[0]["type"], "DEPOSIT")
#         self.assertEqual(transactions[0]["amount"], 500.00)
#         self.assertEqual(transactions[0]["balance_after"], 500.00)
#         self.assertEqual(transactions[0]["timestamp"], self.mock_now)
#
#         self.assertTrue(account.deposit(250.50))
#         self.assertEqual(account.balance, 750.50)
#         self.assertEqual(account._total_capital_contributed, 750.50)
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 2)
#         self.assertEqual(transactions[1]["type"], "DEPOSIT")
#         self.assertEqual(transactions[1]["amount"], 250.50)
#         self.assertEqual(transactions[1]["balance_after"], 750.50)
#         self.assertEqual(transactions[1]["timestamp"], self.mock_now)
#
#     def test_deposit_zero_amount_raises_error(self):
#         """
#         Test that depositing zero amount raises a ValueError.
#         """
#         account = Account(self.account_id)
#         with self.assertRaisesRegex(ValueError, "Deposit amount must be positive."):
#             account.deposit(0)
#         self.assertEqual(account.balance, 0.0)
#         self.assertEqual(account.get_transactions(), [])
#
#     def test_deposit_negative_amount_raises_error(self):
#         """
#         Test that depositing a negative amount raises a ValueError.
#         """
#         account = Account(self.account_id)
#         with self.assertRaisesRegex(ValueError, "Deposit amount must be positive."):
#             account.deposit(-100.00)
#         self.assertEqual(account.balance, 0.0)
#         self.assertEqual(account.get_transactions(), [])
#
#     def test_withdraw_successful(self):
#         """
#         Test a successful withdrawal operation.
#         """
#         account = Account(self.account_id, 1000.00)
#         self.assertTrue(account.withdraw(200.00))
#         self.assertEqual(account.balance, 800.00)
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 2) # Initial deposit + withdrawal
#         self.assertEqual(transactions[1]["type"], "WITHDRAWAL")
#         self.assertEqual(transactions[1]["amount"], 200.00)
#         self.assertEqual(transactions[1]["balance_after"], 800.00)
#         self.assertEqual(transactions[1]["timestamp"], self.mock_now)
#
#     def test_withdraw_insufficient_funds_raises_error(self):
#         """
#         Test that withdrawing more than the current balance raises a ValueError.
#         """
#         account = Account(self.account_id, 100.00)
#         with self.assertRaisesRegex(ValueError, "Insufficient funds for withdrawal."):
#             account.withdraw(200.00)
#         self.assertEqual(account.balance, 100.00) # Balance should remain unchanged
#         self.assertEqual(len(account.get_transactions()), 1) # Only initial deposit
#
#     def test_withdraw_zero_amount_raises_error(self):
#         """
#         Test that withdrawing zero amount raises a ValueError.
#         """
#         account = Account(self.account_id, 100.00)
#         with self.assertRaisesRegex(ValueError, "Withdrawal amount must be positive."):
#             account.withdraw(0)
#         self.assertEqual(account.balance, 100.00)
#         self.assertEqual(len(account.get_transactions()), 1)
#
#     def test_withdraw_negative_amount_raises_error(self):
#         """
#         Test that withdrawing a negative amount raises a ValueError.
#         """
#         account = Account(self.account_id, 100.00)
#         with self.assertRaisesRegex(ValueError, "Withdrawal amount must be positive."):
#             account.withdraw(-50.00)
#         self.assertEqual(account.balance, 100.00)
#         self.assertEqual(len(account.get_transactions()), 1)
#
#     @patch('accounts.get_share_price', side_effect=lambda symbol: {'AAPL': 150.00, 'MSFT': 200.00}.get(symbol.upper(), 100.00))
#     def test_buy_shares_successful(self, mock_get_share_price):
#         """
#         Test successful purchase of shares, including buying new symbols and adding to existing holdings.
#         """
#         account = Account(self.account_id, 2000.00) # Initial balance: 2000
#         # Buy AAPL
#         self.assertTrue(account.buy_shares("AAPL", 5)) # 5 shares * 150.00/share = 750.00 cost
#         self.assertEqual(account.balance, 2000.00 - 750.00) # 1250.00
#         self.assertEqual(account.get_holdings(), {"AAPL": 5})
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 2)
#         self.assertEqual(transactions[1]["type"], "BUY")
#         self.assertEqual(transactions[1]["symbol"], "AAPL")
#         self.assertEqual(transactions[1]["quantity"], 5)
#         self.assertEqual(transactions[1]["price_per_share"], 150.00)
#         self.assertEqual(transactions[1]["amount"], 750.00)
#         self.assertEqual(transactions[1]["balance_after"], 1250.00)
#
#         # Buy MSFT (new symbol)
#         self.assertTrue(account.buy_shares("MSFT", 2)) # 2 shares * 200.00/share = 400.00 cost
#         self.assertEqual(account.balance, 1250.00 - 400.00) # 850.00
#         self.assertEqual(account.get_holdings(), {"AAPL": 5, "MSFT": 2})
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 3)
#
#         # Buy more AAPL (existing symbol)
#         self.assertTrue(account.buy_shares("AAPL", 3)) # 3 shares * 150.00/share = 450.00 cost
#         self.assertEqual(account.balance, 850.00 - 450.00) # 400.00
#         self.assertEqual(account.get_holdings(), {"AAPL": 8, "MSFT": 2}) # 5 + 3 = 8
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 4)
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_buy_shares_insufficient_funds_raises_error(self, mock_get_share_price):
#         """
#         Test that buying shares with insufficient funds raises a ValueError.
#         """
#         account = Account(self.account_id, 100.00) # Balance is 100
#         with self.assertRaisesRegex(ValueError, "Insufficient funds to buy"):
#             account.buy_shares("AAPL", 1) # Cost 150.00
#         self.assertEqual(account.balance, 100.00)
#         self.assertEqual(account.get_holdings(), {})
#         self.assertEqual(len(account.get_transactions()), 1) # Only initial deposit
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_buy_shares_zero_quantity_raises_error(self, mock_get_share_price):
#         """
#         Test that buying zero shares raises a ValueError.
#         """
#         account = Account(self.account_id, 1000.00)
#         with self.assertRaisesRegex(ValueError, "Quantity must be positive."):
#             account.buy_shares("AAPL", 0)
#         self.assertEqual(account.balance, 1000.00)
#         self.assertEqual(account.get_holdings(), {})
#         self.assertEqual(len(account.get_transactions()), 1)
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_buy_shares_negative_quantity_raises_error(self, mock_get_share_price):
#         """
#         Test that buying a negative quantity of shares raises a ValueError.
#         """
#         account = Account(self.account_id, 1000.00)
#         with self.assertRaisesRegex(ValueError, "Quantity must be positive."):
#             account.buy_shares("AAPL", -5)
#         self.assertEqual(account.balance, 1000.00)
#         self.assertEqual(account.get_holdings(), {})
#         self.assertEqual(len(account.get_transactions()), 1)
#
#     @patch('accounts.get_share_price', side_effect=lambda symbol: {'AAPL': 150.00, 'TSLA': 200.00}.get(symbol.upper(), 100.00))
#     def test_sell_shares_successful(self, mock_get_share_price):
#         """
#         Test successful selling of shares, including selling partial and all holdings.
#         """
#         account = Account(self.account_id, 10000.00)
#         account.buy_shares("AAPL", 10) # Cost: 1500. Balance: 8500. Holdings: {'AAPL': 10}
#         account.buy_shares("TSLA", 5)  # Cost: 1000. Balance: 7500. Holdings: {'AAPL': 10, 'TSLA': 5}
#
#         # Sell some AAPL shares
#         self.assertTrue(account.sell_shares("AAPL", 3)) # 3 shares * 150.00/share = 450.00 revenue
#         self.assertEqual(account.balance, 7500.00 + 450.00) # 7950.00
#         self.assertEqual(account.get_holdings(), {"AAPL": 7, "TSLA": 5})
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 4) # Initial deposit + 2 buys + 1 sell
#         self.assertEqual(transactions[3]["type"], "SELL")
#         self.assertEqual(transactions[3]["symbol"], "AAPL")
#         self.assertEqual(transactions[3]["quantity"], 3)
#         self.assertEqual(transactions[3]["price_per_share"], 150.00)
#         self.assertEqual(transactions[3]["amount"], 450.00)
#         self.assertEqual(transactions[3]["balance_after"], 7950.00)
#
#         # Sell all TSLA shares
#         self.assertTrue(account.sell_shares("TSLA", 5)) # 5 shares * 200.00/share = 1000.00 revenue
#         self.assertEqual(account.balance, 7950.00 + 1000.00) # 8950.00
#         self.assertEqual(account.get_holdings(), {"AAPL": 7}) # TSLA should be removed as quantity is 0
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 5)
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_sell_shares_not_enough_shares_raises_error(self, mock_get_share_price):
#         """
#         Test that selling more shares than held raises a ValueError.
#         """
#         account = Account(self.account_id, 1000.00)
#         account.buy_shares("AAPL", 5) # Holdings: {'AAPL': 5}
#
#         with self.assertRaisesRegex(ValueError, "Not enough AAPL shares to sell."):
#             account.sell_shares("AAPL", 10)
#         self.assertEqual(account.get_holdings(), {"AAPL": 5}) # Holdings should be unchanged
#         self.assertEqual(account.balance, 1000.00 - (5 * 150.00)) # Balance unchanged from before attempted sell
#         self.assertEqual(len(account.get_transactions()), 2) # Initial deposit + buy
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_sell_shares_symbol_not_held_raises_error(self, mock_get_share_price):
#         """
#         Test that selling shares of a symbol not held raises a ValueError.
#         """
#         account = Account(self.account_id, 1000.00)
#         account.buy_shares("AAPL", 5)
#
#         with self.assertRaisesRegex(ValueError, "Not enough XYZ shares to sell."):
#             account.sell_shares("XYZ", 1)
#         self.assertEqual(account.get_holdings(), {"AAPL": 5})
#         self.assertEqual(account.balance, 1000.00 - (5 * 150.00))
#         self.assertEqual(len(account.get_transactions()), 2)
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_sell_shares_zero_quantity_raises_error(self, mock_get_share_price):
#         """
#         Test that selling zero shares raises a ValueError.
#         """
#         account = Account(self.account_id, 1000.00)
#         account.buy_shares("AAPL", 5)
#
#         with self.assertRaisesRegex(ValueError, "Quantity must be positive."):
#             account.sell_shares("AAPL", 0)
#         self.assertEqual(account.get_holdings(), {"AAPL": 5})
#         self.assertEqual(len(account.get_transactions()), 2)
#
#     @patch('accounts.get_share_price', return_value=150.00)
#     def test_sell_shares_negative_quantity_raises_error(self, mock_get_share_price):
#         """
#         Test that selling a negative quantity of shares raises a ValueError.
#         """
#         account = Account(self.account_id, 1000.00)
#         account.buy_shares("AAPL", 5)
#
#         with self.assertRaisesRegex(ValueError, "Quantity must be positive."):
#             account.sell_shares("AAPL", -1)
#         self.assertEqual(account.get_holdings(), {"AAPL": 5})
#         self.assertEqual(len(account.get_transactions()), 2)
#
#     def test_get_holdings(self):
#         """
#         Test that get_holdings returns the correct share holdings and a copy.
#         """
#         account = Account(self.account_id, 10000.00)
#         self.assertEqual(account.get_holdings(), {})
#         with patch('accounts.get_share_price', return_value=100.00):
#             account.buy_shares("AAPL", 10)
#             self.assertEqual(account.get_holdings(), {"AAPL": 10})
#             account.buy_shares("MSFT", 5)
#             self.assertEqual(account.get_holdings(), {"AAPL": 10, "MSFT": 5})
#             account.sell_shares("AAPL", 3)
#             self.assertEqual(account.get_holdings(), {"AAPL": 7, "MSFT": 5})
#             account.sell_shares("MSFT", 5)
#             self.assertEqual(account.get_holdings(), {"AAPL": 7}) # MSFT removed when quantity becomes zero
#
#         # Ensure it returns a copy, not the internal dictionary reference
#         holdings = account.get_holdings()
#         holdings["GOOGL"] = 1 # Modify the copy
#         self.assertNotIn("GOOGL", account.get_holdings()) # Original should be unchanged
#
#     @patch('accounts.get_share_price', side_effect=lambda symbol: {'AAPL': 170.00, 'TSLA': 250.00}.get(symbol.upper(), 100.00))
#     def test_get_portfolio_value(self, mock_get_share_price):
#         """
#         Test that get_portfolio_value calculates the total value correctly.
#         """
#         account = Account(self.account_id, 5000.00) # Initial balance: 5000
#         self.assertEqual(account.get_portfolio_value(), 5000.00)
#
#         # Buy AAPL: 10 shares * 170.00/share = 1700.00 cost
#         account.buy_shares("AAPL", 10) # Balance: 5000 - 1700 = 3300. Holdings: {'AAPL': 10}
#         # Portfolio value: 3300 (cash) + 10 * 170 (AAPL) = 3300 + 1700 = 5000
#         self.assertEqual(account.get_portfolio_value(), 5000.00)
#
#         # Buy TSLA: 4 shares * 250.00/share = 1000.00 cost
#         account.buy_shares("TSLA", 4) # Balance: 3300 - 1000 = 2300. Holdings: {'AAPL': 10, 'TSLA': 4}
#         # Portfolio value: 2300 (cash) + 10 * 170 (AAPL) + 4 * 250 (TSLA) = 2300 + 1700 + 1000 = 5000
#         self.assertEqual(account.get_portfolio_value(), 5000.00)
#
#         # Sell some AAPL: 2 shares * 170.00/share = 340.00 revenue
#         account.sell_shares("AAPL", 2) # Balance: 2300 + 340 = 2640. Holdings: {'AAPL': 8, 'TSLA': 4}
#         # Portfolio value: 2640 (cash) + 8 * 170 (AAPL) + 4 * 250 (TSLA) = 2640 + 1360 + 1000 = 5000
#         self.assertEqual(account.get_portfolio_value(), 5000.00)
#
#         # Deposit more funds
#         account.deposit(1000.00) # Balance: 2640 + 1000 = 3640
#         # Portfolio value: 3640 (cash) + 8 * 170 (AAPL) + 4 * 250 (TSLA) = 3640 + 1360 + 1000 = 6000
#         self.assertEqual(account.get_portfolio_value(), 6000.00)
#
#     def test_get_profit_loss(self):
#         """
#         Test that get_profit_loss calculates the profit/loss correctly
#         relative to total capital contributed, considering market price changes.
#         """
#         # Scenario 1: Initial state, no profit/loss
#         account_pl = Account(self.account_id, 1000.00) # Total capital contributed: 1000
#         self.assertEqual(account_pl.get_profit_loss(), 0.0)
#
#         # Scenario 2: Buy shares, then simulate market price changes for evaluation
#         # Patch get_share_price for specific sequence:
#         # 1st call for buy_shares (purchase price: 150)
#         # 2nd call for get_portfolio_value (within buy_shares, still 150)
#         # 3rd call for get_portfolio_value (within get_profit_loss, simulated market price: 160)
#         with patch('accounts.get_share_price', side_effect=[150.00, 150.00, 160.00]) as mock_prices:
#             account_pl.buy_shares("MSFT", 4) # Cost: 4 * 150 = 600. Balance: 400. Holdings: {'MSFT': 4}
#                                             # Total capital contributed: 1000
#             # At this point, initial P&L is 0 if evaluated at purchase price (implicit within buy_shares calling get_portfolio_value)
#             # The next call to get_share_price will be for get_portfolio_value in get_profit_loss.
#             # Portfolio value: 400 (cash) + 4 * 160 (MSFT current market price) = 400 + 640 = 1040
#             # Profit/Loss: 1040 (current portfolio value) - 1000 (total capital contributed) = 40
#             self.assertEqual(account_pl.get_profit_loss(), 40.00)
#
#         # Scenario 3: Deposits and Withdrawals affect capital contributed
#         account_capital = Account("capital_acc", 1000.00)
#         account_capital.deposit(500.00) # Total capital contributed: 1000 + 500 = 1500
#         account_capital.withdraw(200.00) # Withdrawal does NOT affect total capital contributed, only balance
#         # Current cash balance: 1000 (initial) + 500 (deposit) - 200 (withdrawal) = 1300
#         # Portfolio value (only cash): 1300
#         # Profit/Loss: 1300 (current portfolio value) - 1500 (total capital contributed) = -200
#         self.assertEqual(account_capital.get_profit_loss(), -200.00)
#
#         # Scenario 4: Sell at a loss/gain (demonstrates how get_portfolio_value uses current prices)
#         with patch('accounts.get_share_price', side_effect=[100.00, 100.00, 90.00, 90.00]) as mock_prices:
#             account_sell = Account("sell_acc", 1000.00) # Total capital contributed: 1000
#             # Buy shares at 100
#             account_sell.buy_shares("GOOGL", 5) # Cost 5 * 100 = 500. Balance: 500. Holdings: {'GOOGL': 5}
#             self.assertEqual(account_sell.get_profit_loss(), 0.0) # Evaluated at purchase price
#
#             # Sell shares when price has dropped to 90
#             # get_share_price for sell_shares (90.00)
#             # get_share_price for get_portfolio_value (90.00) for P/L calculation
#             account_sell.sell_shares("GOOGL", 2) # Revenue 2 * 90 = 180. Balance: 500 + 180 = 680. Holdings: {'GOOGL': 3}
#             # Total Capital Contributed: 1000
#             # Current Portfolio Value: 680 (cash) + 3 * 90 (GOOGL current market value) = 680 + 270 = 950
#             # Profit/Loss: 950 (current portfolio value) - 1000 (total capital contributed) = -50
#             self.assertEqual(account_sell.get_profit_loss(), -50.00)
#
#     def test_get_transactions(self):
#         """
#         Test that get_transactions returns all historical transactions and a copy.
#         """
#         account = Account(self.account_id)
#         self.assertEqual(account.get_transactions(), [])
#
#         account.deposit(100.00)
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 1)
#         self.assertEqual(transactions[0]["type"], "DEPOSIT")
#         self.assertEqual(transactions[0]["amount"], 100.00)
#         self.assertEqual(transactions[0]["balance_after"], 100.00)
#         self.assertEqual(transactions[0]["timestamp"], self.mock_now)
#
#         account.withdraw(50.00)
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 2)
#         self.assertEqual(transactions[1]["type"], "WITHDRAWAL")
#         self.assertEqual(transactions[1]["amount"], 50.00)
#         self.assertEqual(transactions[1]["balance_after"], 50.00) # 100 - 50 = 50
#         self.assertEqual(transactions[1]["timestamp"], self.mock_now)
#
#         # Test buying
#         with patch('accounts.get_share_price', return_value=10.00):
#             account.buy_shares("ABC", 3) # Cost 3 * 10 = 30. Balance: 50 - 30 = 20
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 3)
#         self.assertEqual(transactions[2]["type"], "BUY")
#         self.assertEqual(transactions[2]["symbol"], "ABC")
#         self.assertEqual(transactions[2]["quantity"], 3)
#         self.assertEqual(transactions[2]["price_per_share"], 10.00)
#         self.assertEqual(transactions[2]["amount"], 30.00)
#         self.assertEqual(transactions[2]["balance_after"], 20.00)
#         self.assertEqual(transactions[2]["timestamp"], self.mock_now)
#
#
#         # Test selling
#         with patch('accounts.get_share_price', return_value=15.00):
#             account.sell_shares("ABC", 1) # Revenue 1 * 15 = 15. Balance: 20 + 15 = 35
#         transactions = account.get_transactions()
#         self.assertEqual(len(transactions), 4)
#         self.assertEqual(transactions[3]["type"], "SELL")
#         self.assertEqual(transactions[3]["symbol"], "ABC")
#         self.assertEqual(transactions[3]["quantity"], 1)
#         self.assertEqual(transactions[3]["price_per_share"], 15.00)
#         self.assertEqual(transactions[3]["amount"], 15.00)
#         self.assertEqual(transactions[3]["balance_after"], 35.00)
#         self.assertEqual(transactions[3]["timestamp"], self.mock_now)
#
#         # Ensure it returns a copy, not the internal list reference
#         transactions_copy = account.get_transactions()
#         transactions_copy.append({"type": "FAKE"}) # Modify the copy
#         self.assertEqual(len(account.get_transactions()), 4) # Original should be unchanged
#
# if __name__ == '__main__':
#     unittest.main()
